# %%
import pandas as pd
from glob import glob

dataframes = []
for f in glob("*.json"):
    dataframes.append(pd.read_json(f))


d1 = pd.read_json('20160101_012400_newshour.asr.json')
d2 = pd.read_json('20160101_105100_best_of_today.asr.json')
d3 = pd.read_json('20160101_124600_best_of_today.asr.json')
d4 = pd.read_json('20160101_130000_the_fifth_floor.asr.json')
d5 = pd.read_json('20160101_150300_world_at_one.asr.json')
d6 = pd.read_json('20160101_153000_newshour.asr.json')
d7 = pd.read_json('20160101_154500_global_news_podcast.asr.json')
d8 = pd.read_json('20160101_184100_world_have_your_say.asr.json')
d9 = pd.read_json('20160101_184300_six_oclock_news.asr.json')

data = pd.concat(dataframes)
data
# Out:
#     classes                                           segments  \
# 0  [speech]  [{'classId': 'speech', 'spokenWords': [{'wordE...
# 0  [speech]  [{'classId': 'speech', 'spokenWords': [{'wordE...
# 0  [speech]  [{'classId': 'speech', 'spokenWords': [{'wordE...
# 0  [speech]  [{'classId': 'speech', 'spokenWords': [{'wordE...
# 0  [speech]  [{'classId': 'speech', 'spokenWords': [{'wordE...
# 0  [speech]  [{'classId': 'speech', 'spokenWords': [{'wordE...
# 0  [speech]  [{'classId': 'speech', 'spokenWords': [{'wordE...
# 0  [speech]  [{'classId': 'speech', 'spokenWords': [{'wordE...
# 0  [speech]  [{'classId': 'speech', 'spokenWords': [{'wordE...
#
#                                             speakers
# 0                                     [s0002, s0001]
# 0                              [s0003, s0002, s0001]
# 0                              [s0001, s0003, s0002]
# 0         [s0005, s0006, s0003, s0001, s0004, s0002]
# 0                       [s0001, s0003, s0002, s0004]
# 0  [s0003, s0004, s0006, s0008, s0005, s0002, s00...
# 0  [s0003, s0008, s0001, s0004, s0002, s0009, s00...
# 0                [s0001, s0004, s0003, s0005, s0002]
# 0                [s0001, s0002, s0004, s0005, s0003]

# %%
word_list = []
confidence_list  = []
datawc = pd.DataFrame()
for words in data['segments']:
    for i in words:
        for word in i['spokenWords']:
            word_list.append(word['wordId'])
            confidence_list.append(word['wordConfidence'])
        #print(i['spokenWords'][0]['wordId'])
datawc['word'] = word_list
datawc['confidence'] = confidence_list

# %%
datawc
# Out:
#               word  confidence
# 0            HELLO         1.0
# 1              AND         1.0
# 2          WELCOME         1.0
# 3               TO         1.0
# 4             NEWS         1.0
# 5              OUR         1.0
# 6             FROM         1.0
# 7              THE         1.0
# 8           B.B.C.         1.0
# 9            WORLD         1.0
# 10         SERVICE         1.0
# 11          COMING         1.0
# 12              TO         1.0
# 13            LIVE         1.0
# 14            FROM         1.0
# 15          LONDON         1.0
# 16             I'M         1.0
# 17              AT         1.0
# 18           LEAST         1.0
# 19             YOU         1.0
# 20             SET         1.0
# 21              IN         1.0
# 22          COMING         1.0
# 23              UP         1.0
# 24            THEM         1.0
# 25              IN         1.0
# 26             OUR         1.0
# 27            LAST         1.0
# 28         PROGRAM         1.0
# 29              OF         1.0
# ...            ...         ...
# 55275           DU         1.0
# 55276          BON         1.0
# 55277            I         1.0
# 55278         JUST         1.0
# 55279         FEET         1.0
# 55280         FROM         1.0
# 55281          THE         1.0
# 55282     INFINITE         1.0
# 55283       B.B.C.         1.0
# 55284         NEWS         1.0
# 55285          FOR         1.0
# 55286         MORE         1.0
# 55287      REPORTS         1.0
# 55288          AND         1.0
# 55289  INFORMATION         1.0
# 55290       SEARCH         1.0
# 55291       ONLINE         1.0
# 55292          FOR         1.0
# 55293        RADIO         1.0
# 55294          FOR         1.0
# 55295          SIX         1.0
# 55296      O'CLOCK         1.0
# 55297         NEWS         1.0
# 55298           OR         1.0
# 55299          USE         1.0
# 55300          THE         1.0
# 55301      HASHTAG         1.0
# 55302        RADIO         1.0
# 55303          FOR         1.0
# 55304          SEX         1.0
#
# [55305 rows x 2 columns]

# %%
import seaborn as sns, numpy as np
# %matplotlib inline
x = pd.Series(datawc['confidence'], name="Word Confidence")
chart = sns.distplot(x)
chart.set_title('Distribution of Word Confidence')

# %%
import html5lib 
import pandas as pd
mp2015 = pd.read_html("https://en.wikipedia.org/wiki/List_of_MPs_elected_in_the_United_Kingdom_general_election,_2015")

# %%
def extract_name(duplicate_name):
    """Extracts names from the wikipedia column, as the first name is there twice"""
    first_name = ""
    last_c = " "
    for c in duplicate_name:
        if (last_c != " " and c.isupper()):#If the name repeats, we found the first name
            return first_name
        else:#We haven't found the first name, continue and add the character to it
            first_name += c
            last_c = c
            

mps = pd.DataFrame()
last_name = []
first_name = []
title = []
party = []
titles = ["The Hon. ","Sir ","Dame "]
for mp in mp2015[4][4][1:]:
    one_party = mp.split('(')
    party_symbol = one_party[1].split(')')[0]
    party.append(party_symbol)
    one_name = mp.split(",")
    last_name.append(one_name[0])
    if ('Jr.' in one_name[1]):
        first_name_with_title = extract_name(one_name[2][1:])
        has_title = False
        for t in titles:
            if t in first_name_with_title:
                split_name_title = first_name_with_title.split(t)
                title.append(split_name_title[0])
                first_name.append(split_name_title[1])
                has_title = True
                break
        if not has_title:
            first_name.append(first_name_with_title)
            title.append("")
    else:
        first_name_with_title = extract_name(one_name[1][1:])
        has_title = False
        for t in titles:
            if first_name_with_title is not None and t in first_name_with_title:
                split_name_title = first_name_with_title.split(t)
                title.append(t)
                first_name.append(split_name_title[1])
                has_title = True
                break
        if not has_title:
            first_name.append(first_name_with_title)
            title.append("")
mps['title'] = title
mps['first_name'] = first_name
mps['last_name'] = last_name
mps['party'] = party

# %%
mps
# Out:
#          title first_name  last_name    party
# 0    The Hon.     Stephen    Kinnock        L
# 1                    Guto       Bebb        C
# 2                  Kirsty   Blackman      SNP
# 3                  Callum     McCaig      SNP
# 4                    Neil       Gray      SNP
# 5         Sir      Gerald    Howarth        C
# 6                   Wendy     Morton        C
# 7                  Graham      Brady        C
# 8                    Mark       Tami        L
# 9                   Nigel      Mills        C
# 10                   Mike       Weir      SNP
# 11                  Hywel   Williams       PC
# 12                Brendan     O'Hara      SNP
# 13                   Nick    Herbert        C
# 14                 Gloria   De Piero        L
# 15                 Damian      Green        C
# 16                 Angela     Rayner        L
# 17                  David  Lidington        C
# 18                  Corri     Wilson      SNP
# 19   The Hon.    Victoria    Prentis        C
# 20                 Eilidh  Whiteford      SNP
# 21                   None      Hodge        L
# 22                    Dan     Jarvis        L
# 23                Michael     Dugher        L
# 24                   John   Woodcock  L Co-op
# 25                   John      Baron        C
# 26                  Maria     Miller        C
# 27                   John       Mann        L
# 28                    Ben    Howlett        C
# 29                     Jo        Cox        L
# ..         ...        ...        ...      ...
# 620                 Karen       Buck        L
# 621                   Tim     Farron       LD
# 622                  John    Penrose        C
# 623                  Lisa      Nandy        L
# 624               Stephen    Hammond        C
# 625                 Steve      Brine        C
# 626                  Adam    Afriyie        C
# 627                Alison   McGovern        L
# 628              Margaret  Greenwood        L
# 629                 Priti      Patel        C
# 630                 David    Cameron        C
# 631              Jonathan       Lord        C
# 632                  John    Redwood        C
# 633                  Emma   Reynolds        L
# 634                   Pat   McFadden        L
# 635                   Rob     Marris        L
# 636  The Hon.       Robin     Walker        C
# 637                   Sue     Hayman        L
# 638               Barbara     Keeley        L
# 639       Sir       Peter  Bottomley        C
# 640                  Mark  Pritchard        C
# 641                   Ian      Lucas        L
# 642                 Steve      Baker        C
# 643                   Ben    Wallace        C
# 644                  Mark    Garnier        C
# 645                  Mike       Kane        L
# 646                Marcus       Fysh        C
# 647                Albert       Owen        L
# 648               Rachael    Maskell  L Co-op
# 649                Julian     Sturdy        C
#
# [650 rows x 4 columns]

# %%
last_nameU =[x.upper() for x in last_name]
print(last_nameU)
for i in word_list:
    for j in last_nameU:
        if j == i:
            print(i)
            break
# Out:
# ['KINNOCK', 'BEBB', 'BLACKMAN', 'MCCAIG', 'GRAY', 'HOWARTH', 'MORTON', 'BRADY', 'TAMI', 'MILLS', 'WEIR', 'WILLIAMS', "O'HARA", 'HERBERT', 'DE PIERO', 'GREEN', 'RAYNER', 'LIDINGTON', 'WILSON', 'PRENTIS', 'WHITEFORD', 'HODGE', 'JARVIS', 'DUGHER', 'WOODCOCK', 'BARON', 'MILLER', 'MANN', 'HOWLETT', 'COX', 'ELLISON', 'GRIEVE', 'STEWART', 'FULLER', 'ROBINSON', 'DODDS', 'MCDONNELL', 'MASKEY', 'COYLE', 'TREVELYAN', 'KERR', 'ALI', 'STUART', 'MERRIMAN', 'EVENNETT', 'FIELD', 'STUART', 'DROMEY', 'GODSIFF', 'BYRNE', 'MAHMOOD', 'BURDEN', 'MAHMOOD', 'MCCABE', 'PHILLIPS', 'GOODMAN', 'HOLLERN', 'STRINGER', 'MAYNARD', 'MARSDEN', 'SMITH', 'ANDERSON', 'CAMPBELL', 'GIBB', 'SKINNER', 'CRAUSBY', 'QURESHI', 'GREEN', 'DOWD', 'WARMAN', 'TREDINNICK', 'ELLWOOD', 'BURNS', 'LEE', 'HUSSAIN', 'CUMMINS', 'SHAH', 'CLEVERLY', 'DAVIES', 'BUTLER', 'GARDINER', 'CADBURY', 'PICKLES', 'MOON', 'LIDDELL-GRAINGER', 'PERCY', 'KIRBY', 'LUCAS', 'MCCARTHY', 'LESLIE', 'SMYTH', 'DEBBONAIRE', 'SIMPSON', 'NEILL', 'JAVID', 'WALKER', 'SOUBRY', 'BERCOW', 'COOPER', 'GRIFFITHS', 'NUTTALL', 'LEWIS', 'CHURCHILL', 'DAVID', 'MONAGHAN', 'WHITTAKER', 'HARMAN', 'EUSTICE', 'ZEICHNER', 'MILLING', 'BRAZIER', 'STEVENS', 'WILLIAMS', 'DOUGHTY', 'BRENNAN', 'STEVENSON', 'EDWARDS', 'HART', 'BRAKE', 'HARRIS', 'WHITFORD', 'STRIDE', 'POULTER', 'WILLIAMS', 'ARGAR', 'CROUCH', 'ROBINSON', 'BURNS', 'HANDS', 'CHALK', 'GILLAN', 'PERKINS', 'TYRIE', 'DUNCAN SMITH', 'DONELAN', 'VILLIERS', 'HOYLE', 'CHOPE', 'FIELD', 'MATHESON', 'CARSWELL', 'VICKERS', 'JONES', 'JONES', 'BOSWELL', 'QUINCE', 'MCCARTNEY', 'BRUCE', 'REED', 'PURSGLOVE', 'CLIFTON-BROWN', 'FLETCHER', 'ROBINSON', 'CUNNINGHAM', 'SMITH', 'TIMPSON', 'BARWELL', 'REED', 'PHILP', 'MCDONALD', 'CLWYD', 'CRUDDAS', 'CHAPMAN', 'JOHNSON', 'HEATON-HARRIS', 'HANSON', 'GWYNNE', 'SOLLOWAY', 'BECKETT', 'MCLOUGHLIN', 'PERRY', 'SHERRIFF', 'FLINT', 'WINTERTON', 'MILIBAND', 'ELPHICKE', 'AUSTIN', 'WOOD', 'HAYES', 'ARKLESS', 'MUNDELL', 'HOSIE', 'LAW', 'CHAPMAN', 'BLACKMAN-WOODS', 'SAVILLE-ROBERTS', 'HUQ', 'POUND', 'SHARMA', 'MORRIS', 'WILSON', 'SWIRE', 'NICOLSON', 'TIMMS', 'HINDS', 'CAMERON', 'CAMPBELL', 'KEREVAN', 'OSWALD', 'GYIMAH', 'LOUGHTON', 'KNIGHT', 'ANSELL', 'DAVIES', 'SANDBACH', 'SHEPPARD', 'BROCK', 'MURRAY', 'CHERRY', 'THOMSON', 'OSAMOR', 'MADDERS', 'SHELBROOKE', 'EFFORD', 'RYAN', 'BURROWES', 'LAING', 'GRAYLING', 'THROUP', 'PEARCE', 'RAAB', 'BRADSHAW', 'MCNALLY', 'FERNANDES', 'WHATELY', 'MALHOTRA', 'ELLIOTT', 'LOPRESTI', 'FREER', 'COLLINS', 'HARPER', 'DURKAN', 'MENZIES', 'LEIGH', 'EAGLE', 'MEARNS', 'COAKER', 'CHISHTI', 'THEWLISS', 'MCGARRY', 'GRADY', 'MCLAUGHLIN', 'MONAGHAN', 'MCDONALD', 'STEPHENS', 'GRANT', 'GRAHAM', 'SALMOND', 'DINENAGE', 'DAVIES', 'BOLES', 'HOLLOWAY', 'ONN', 'LEWIS', 'PENNYCOOK', 'MILTON', 'ABBOTT', 'HILLIER', 'MORRIS', 'LYNCH', 'DAVIS', 'TWIGG', 'SLAUGHTER', 'SIDDIQ', 'GARNIER', 'HALFON', 'JONES', 'BLACKMAN', 'THOMAS', 'WRIGHT', 'JENKIN', 'RUDD', 'MAK', 'MCDONNELL', 'WRAGG', 'PENNING', 'TRICKETT', 'OFFORD', 'HOWELL', 'NORMAN', 'PRISK', 'DOWDEN', 'OPPERMAN', 'MCINNES', 'BINGHAM', 'LILLEY', 'STARMER', 'WATKINSON', 'WEST', 'QUIN', 'PHILLIPSON', 'KYLE', 'SHEERMAN', 'DJANOGLY', 'JONES', 'STREETING', 'GAPES', 'COWAN', 'HENDRY', 'GUMMER', 'TURNER', 'CORBYN', 'THORNBERRY', 'EVANS', 'HEPBURN', 'HOPKINS', 'WRIGHT', 'BORWICK', 'HOLLOBONE', 'BROWN', 'BERRY', 'TURNER', 'JOHNSON', 'JOHNSON', 'SKIDMORE', 'MULLIN', 'HOWARTH', 'DONALDSON', 'CRAWLEY', 'SMITH', 'BENN', 'BURGON', 'HAMILTON', 'MULHOLLAND', 'REEVES', 'VAZ', 'ASHWORTH', 'KENDALL', 'BURNHAM', 'CAULFIELD', 'ALEXANDER', 'DOWD', 'FOXCROFT', 'CRYER', 'FABRICANT', 'MCCARTNEY', 'DAY', 'ELLMAN', 'ROTHERAM', 'BERGER', 'TWIGG', 'BARDELL', 'GRIFFITH', 'MORGAN', 'ATKINS', 'DUNNE', 'HOPKINS', 'SHUKER', 'RUTLEY', 'MAY', 'GRANT', 'FOVARGUE', 'WHITTINGDALE', 'POWELL', 'KAUFMAN', 'SMITH', 'MEALE', 'HOLLINGBERY', 'SPELMAN', 'JONES', 'DORRIES', 'LATHAM', 'TOMLINSON', 'FREEMAN', 'SOAMES', 'MOLLOY', 'HUDDLESTON', 'MCDONALD', 'BLENKINSOP', 'THOMPSON', 'LANCASTER', 'STEWART', 'MCDONAGH', 'BERESFORD', 'DAVIES', 'DAVIES', 'ROB ...
# BUCK
# GLASS
# DAY
# DAY
# FIELD
# MAY
# PARISH
# MAY
# MAY
# DOUBLE
# JAMES
# POW
# BURNS
# DAY
# WILLIAMS
# WEST
# BRYANT
# GRANT
# HAMILTON
# MAY
# ALEXANDER
# MILTON
# BRYANT
# MAY
# JAMES
# LORD
# REES
# MOON
# MOON
# DAY
# MAY
# LORD
# REES
# JAMES
# DAVID
# CAMERON
# DAVID
# CAMERON
# CAMPBELL
# FLETCHER
# THOMAS
# SMITH
# CAMPBELL
# ANDREW
# CAMPBELL
# CAMPBELL
# LORD
# THOMAS
# DAY
# AUSTIN
# ANDREW
# LORD
# CAMPBELL
# CAMPBELL
# CAMPBELL
# HARRIS
# MORGAN
# GREEN
# WOOD
# DAVID
# DAVID
# DAVID
# DAVID
# CAMPBELL
# MAY
# DOUBLE
# CAMPBELL
# CAMPBELL
# MAIN
# CAMPBELL
# BLACK
# GRAY
# THOMPSON
# GRAY
# THOMPSON
# DAY
# DAY
# LORD
# DAY
# WHITE
# DAY
# DAY
# HANDS
# BLACKMAN
# CAMPBELL
# ANDREW
# BRUCE
# ALDOUS
# BONE
# CAMPBELL
# CAMPBELL
# MAIN
# POUND
# WHEELER
# DAVID
# HALL
# HANDS
# DAY
# GREEN
# GOODWILL
# PENROSE
# DOUBLE
# GRAY
# MAIN
# MAIN
# MAIN
# DAY
# DAY
# BLACK
# DAVID
# GLASS
# LORD
# DAVID
# GREENWOOD
# DAY
# ALLEN
# DAVIS
# CAMPBELL
# DAY
# DAY
# WEST
# MAIN
# LEE
# DAY
# DAY
# HANDS
# GREEN
# GRANT
# HANDS
# HANCOCK
# BLACK
# MAY
# EVANS
# LUCAS
# LUCAS
# DAY
# DAY
# MAY
# MAY
# EVANS
# DAVID
# CAMERON
# LORD
# DAVID
# CAMERON
# HALL
# FIELD
# HALL
# ENGEL
# DAY
# HANDS
# DAY
# LEE
# DAY
# BRUCE
# CHERRY
# OWEN
# DAY
# DAY
# DAY
# DAY
# DOUBLE
# DAY
# WEST
# HANDS
# CAMERON
# MAIN
# MILLER
# THOMAS
# CAMERON
# MAIN
# MAY
# JONES
# JAMES
# ROBINSON
# KENDALL
# MAY
# JAMES
# CAMPBELL
# JAMES
# JAMES
# MAY
# MAY
# JAMES
# FIELD
# WEST
# WEST
# WEST
# WEST
# JAMES
# MAIN
# MAIN
# MAIN
# WEST
# HANDS
# WEST
# JAMES
# JAMES
# JAMES
# CAMPBELL
# JAMES
# CAMERON
# JAMES
# JAMES
# FIELD
# DOUBLE
# MAY
# BLACK
# CASH
# JAMES
# ROBINSON
# WEST
# LAW
# MAIN
# WHITE
# JAMES
# GREEN
# JAMES
# MAY
# JAMES
# MOON
# DOUBLE
# JAMES
# WHITE
# JONES
# JAMES
# CAMPBELL
# DAY
# DAY
# DAY
# MAIN
# DAY
# HANDS
# HANDS
# HANDS
# DAY
# DAY
# NEWTON
# MOON
# HANDS
# GLASS
# REES
# GREEN
# MAIN
# DAY
# HANDS
# DAY
# MAIN
# BLACK
# FIELD
# LORD
# DAY
# DAY
# DAY
# DAY
# DAY
# MAY
# DAVID
# DAY
# WEST
# GREEN
# MAY
# GREEN
# DAY
# MAIN
# MAY
# MAY
# MILLER
# MAY
# MAY
# DAVIS
# CAMPBELL
# DAY
# DAY
# HUNT
# BLACK
# DAVID
# GREEN
# LORD
# JOHNSON
# DAY
# FREEMAN
# DAY
# DAY
# DAY
# BONE
# DAVID
# DAY

# %%
first_nameU = [x.upper() if x is not None else "MARGERET" for x in first_name]

print(first_nameU)
# Out:
# ['STEPHEN', 'GUTO', 'KIRSTY', 'CALLUM', 'NEIL', 'GERALD', 'WENDY', 'GRAHAM', 'MARK', 'NIGEL', 'MIKE', 'HYWEL', 'BRENDAN', 'NICK', 'GLORIA', 'DAMIAN', 'ANGELA', 'DAVID', 'CORRI', 'VICTORIA', 'EILIDH', 'MARGERET', 'DAN', 'MICHAEL', 'JOHN', 'JOHN', 'MARIA', 'JOHN', 'BEN', 'JO', 'JANE', 'DOMINIC', 'BOB', 'RICHARD', 'GAVIN', 'NIGEL', 'ALASDAIR', 'PAUL', 'NEIL', 'ANNE-', 'CALUM', 'RUSHANARA', 'GRAHAM', 'HUW', 'DAVID', 'FRANK', 'GISELA', 'JACK', 'ROGER', 'LIAM', 'SHABANA', 'RICHARD', 'KHALID', 'STEVE', 'JESS', 'HELEN', 'KATE', 'GRAHAM', 'PAUL', 'GORDON', 'NICK', 'DAVID', 'RONNIE', 'NICK', 'DENNIS', 'DAVID', 'YASMIN', 'CHRIS', 'PETER', 'MATT', 'DAVID', 'TOBIAS', 'CONOR', 'PHILLIP', 'IMRAN', 'JUDITH', 'NAZ', 'JAMES', 'CHRISTOPHER', 'DAWN', 'BARRY', 'RUTH', 'ERIC', 'MADELEINE', 'IAN', 'ANDREW', 'SIMON', 'CAROLINE', 'KERRY', 'CHARLOTTE', 'KARIN', 'THANGAM', 'KEITH', 'BOB', 'SAJID', 'CHARLES', 'ANNA', 'JOHN', 'JULIE', 'ANDREW', 'DAVID', 'IVAN', 'JO', 'WAYNE', 'PAUL', 'CRAIG', 'HARRIET', 'GEORGE', 'DANIEL', 'AMANDA', 'JULIAN', 'JO', 'CRAIG', 'STEPHEN', 'KEVIN', 'JOHN', 'JONATHAN', 'SIMON', 'TOM', 'REBECCA', 'PHILIPPA', 'MEL', 'DANIEL', 'MARK', 'EDWARD', 'TRACEY', 'MARY', 'SIMON', 'GREG', 'ALEX', 'CHERYL', 'TOBY', 'ANDREW', 'IAIN', 'MICHELLE', 'THERESA', 'LINDSAY', 'CHRISTOPHER', 'MARK', 'CHRIS', 'DOUGLAS', 'MARTIN', 'SUSAN ELAN', 'DAVID', 'PHIL', 'WILL', 'JASON', 'FIONA', 'JAMIE', 'TOM', 'GEOFFREY', 'COLLEEN', 'GEOFFREY', 'JIM', 'HENRY', 'EDWARD', 'GAVIN', 'STEVE', 'CHRIS', 'STUART', 'ANN', 'JON', 'JENNY', 'GARETH', 'CHRIS', 'DAVID', 'ANDREW', 'AMANDA', 'MARGARET', 'PATRICK', 'CLAIRE', 'PAULA', 'CAROLINE', 'ROSIE', 'ED', 'CHARLIE', 'IAN', 'MIKE', 'HELEN', 'RICHARD', 'DAVID', 'STEWART', 'CHRIS', 'DOUGLAS', 'ROBERTA', 'LIZ', 'RUPA', 'STEPHEN', 'VIRENDRA', 'GRAHAME', 'SAMMY', 'HUGO', 'JOHN', 'STEPHEN', 'DAMIAN', 'LISA', 'GREGORY', 'GEORGE', 'KIRSTEN', 'SAM', 'TIM', 'GREG', 'CAROLINE', 'MIMS', 'ANTOINETTE', 'TOMMY', 'DEIDRE', 'IAN', 'JOANNA', 'MICHELLE', 'KATE', 'JUSTIN', 'ALEC', 'CLIVE', 'JOAN', 'DAVID', 'ELEANOR', 'CHRIS', 'MAGGIE', 'TERESA', 'DOMINIC', 'BEN', 'JOHN', 'SUELLA', 'HELEN', 'SEEMA', 'TOM', 'JACK', 'MIKE', 'DAMIAN', 'MARK', 'MARK', 'MARK', 'EDWARD', 'MARIA', 'IAN', 'VERNON', 'REHMAN', 'ALISON', 'NATALIE', 'PATRICK', 'ANNE', 'CAROL', 'STEWART', 'CHRIS', 'PETER', 'RICHARD', 'ALEX', 'CAROLINE', 'BYRON', 'NICHOLAS', 'ADAM', 'MELANIE', 'BRANDON', 'MATTHEW', 'ANNE', 'DIANE', 'MEG', 'JAMES', 'HOLLY', 'DAVID', 'DEREK', 'ANDY', 'TULIP', 'EDWARD', 'ROBERT', 'ANDREW', 'BOB', 'GARETH', 'IAIN', 'BERNARD', 'AMBER', 'ALAN', 'JOHN', 'WILLIAM', 'MIKE', 'JON', 'MATTHEW', 'JOHN', 'JESSE', 'MARK', 'OLIVER', 'GUY', 'LIZ', 'ANDREW', 'PETER', 'KEIR', 'ANGELA', 'CATHERINE', 'JEREMY', 'BRIDGET', 'PETER', 'BARRY', 'JONATHAN', 'GRAHAM', 'WES', 'MIKE', 'RONNIE', 'DREW', 'BEN', 'ANDREW', 'JEREMY', 'EMILY', 'CHRIS', 'STEPHEN', 'KRIS', 'JEREMY', 'MARGERET', 'PHILIP', 'ALAN', 'JAMES', 'KARL', 'DIANA', 'ALAN', 'CHRIS', 'ROGER', 'GEORGE', 'JEFFREY', 'ANGELA', 'CAT', 'HILARY', 'RICHARD', 'FABIAN', 'GREG', 'RACHEL', 'KEITH', 'JON', 'LIZ', 'ANDY', 'MARIA', 'HEIDI', 'JIM', 'VICKY', 'JOHN', 'MICHAEL', 'KARL', 'MARTYN', 'LOUISE', 'STEVE', 'LUCIANA', 'STEPHEN', 'HANNAH', 'NIA', 'NICKY', 'VICTORIA', 'PHILIP', 'KELVIN', 'GAVIN', 'DAVID', 'THERESA', 'HELEN', 'YVONNE', 'JOHN', 'LUCY', 'GERALD', 'JEFF', 'ALAN', 'GEORGE', 'CAROLINE', 'GERALD', 'NADINE', 'PAULINE', 'MICHAEL', 'GEORGE', 'NICHOLAS', 'FRANCIE', 'NIGEL', 'ANDY', 'TOM', 'OWEN', 'MARK', 'IAIN', 'SIOBHAIN', 'PAUL', 'DAVID', 'GLYN', 'ANGUS', 'DAVID', 'ANDREA', 'MARION', 'ANGUS', 'CHRISTINA', 'JULIAN', 'DESMOND', 'ROBERT', 'RICHARD', 'CHINYELU', 'NICK', 'CATHERINE', 'PAUL', 'JESSICA', 'PAUL', 'MICKEY', 'ANNE MARIE', 'YVETTE', 'IAN', 'PATRICIA', 'SCOTT', 'PETER', 'SIMON', 'MARGERET', 'KEVAN', 'ALISTAIR', 'STEPHEN', 'NATASCHA', 'STEPHEN', 'RANIL', 'OLIVER', 'JACOB', 'BILL', 'NORMAN', 'OWEN', 'LIAM', 'JUSTIN', 'ROGER', 'MARY', 'CRAIG', 'SHAILESH', 'PAT', 'KIT', 'ANDREW', 'HENRY', 'JAMES', 'MICHAEL', 'DAVID', 'CHLOE', 'CLI ...

# %%
#for q in word_list:
#    for p in first_nameU:
#        if p == q:
#            print(q)
for q in range(0,len(word_list)):
    for p in first_nameU:
        if p == word_list[q] and p != "WILL":
            print(q,word_list[q])
            break
# Out:
# 186 MARK
# 244 MARY
# 815 PATRICK
# 1375 PATRICK
# 1808 MIKE
# 2656 AMANDA
# 3223 SUE
# 3340 JAMES
# 3705 SIMON
# 3706 JACK
# 3860 MARK
# 4107 LISA
# 4534 MARCUS
# 4920 MARCUS
# 4921 GEORGE
# 5564 CHARLES
# 5667 TIM
# 5687 GRANT
# 5765 BEN
# 5980 ERIC
# 6009 GEORGE
# 6147 NICK
# 6288 PATRICK
# 6389 TIM
# 6462 JAMES
# 6474 MARTIN
# 7114 ELEANOR
# 7130 DAN
# 7437 MARTIN
# 7443 JAMES
# 7608 DAVID
# 7814 IAN
# 8328 DAVID
# 8585 ADAM
# 8693 JANE
# 8720 ANDREW
# 9199 ADAM
# 9385 ANDREW
# 9878 RUTH
# 9957 NICHOLAS
# 10124 DANNY
# 10427 DAVID
# 10454 CAROLINE
# 10461 DAVID
# 10533 DAVID
# 10608 KEITH
# 10679 DAVID
# 10734 MATTHEW
# 10932 TOBY
# 11733 JANE
# 11756 SIMON
# 11784 JACK
# 12400 KATE
# 12492 SIMON
# 12496 JACK
# 13225 GUY
# 13505 BILL
# 13917 JANE
# 13991 ANDREW
# 14421 JIM
# 14551 JOHN
# 14652 JANE
# 14682 JANE
# 14940 MATTHEW
# 15110 MATTHEW
# 15403 DAVID
# 16365 GUY
# 16815 RICHARD
# 17129 GUY
# 18140 ANNA
# 18700 PAUL
# 18770 TOM
# 18911 DAVID
# 18968 JOHN
# 19387 MARCUS
# 19388 GEORGE
# 19428 DAWN
# 19562 PETER
# 19608 GEORGE
# 19615 TOM
# 19678 GEORGE
# 19725 DAVID
# 20495 GORDON
# 21285 BARRY
# 21903 GRANT
# 22090 GUY
# 22551 PAUL
# 22982 KELLY
# 23249 STEVEN
# 23863 STEPHEN
# 23881 DAVID
# 23995 PETER
# 24106 FRANK
# 25129 FRANK
# 25169 DAVID
# 25705 DIANA
# 26101 DESMOND
# 27006 GUY
# 27335 ANGUS
# 27351 MARCUS
# 27352 GEORGE
# 27706 MARCUS
# 27707 GEORGE
# 27732 SIMON
# 28440 SIMON
# 28465 BILL
# 28989 MICKEY
# 29272 JUSTIN
# 29488 GREGORY
# 30315 GREGORY
# 30417 CAT
# 30507 GREGORY
# 30609 AMANDA
# 30623 OWEN
# 32954 MICHAEL
# 33250 MICKEY
# 33397 SUE
# 34667 VALERIE
# 34776 JOHN
# 34818 JAMES
# 34820 BRIDGET
# 34999 JAMES
# 35078 BRIDGET
# 35278 JAMES
# 35279 ROBIN
# 35437 JAMES
# 35439 JOHN
# 35458 BRIDGET
# 35591 BRIDGET
# 35935 JOHN
# 36053 JAMES
# 36734 JAMES
# 36858 BRIDGET
# 37593 JOHN
# 37813 BRIDGET
# 38206 JAMES
# 38456 JAMES
# 38599 JAMES
# 38623 JAMES
# 38631 JOHN
# 38869 BRIDGET
# 38902 WILLIAM
# 39071 JOHN
# 39202 JAMES
# 39277 BRIDGET
# 39390 BRIDGET
# 39740 JAMES
# 40366 JOHN
# 40600 JOHN
# 40791 GUY
# 41369 JAMES
# 42406 JAMES
# 42706 JAMES
# 42917 BRIDGET
# 42920 JAMES
# 43175 NEIL
# 43403 JOHN
# 43404 JOHN
# 43422 LISA
# 43570 JAMES
# 43812 BRIDGET
# 43940 JOHN
# 43973 JOHN
# 43974 KERRY
# 44153 MARK
# 44235 JAMES
# 44237 JOHN
# 44240 BRIDGET
# 45038 ANDY
# 45039 ANDY
# 45397 IVAN
# 45665 CHRISTOPHER
# 47143 JOHN
# 47204 MARTIN
# 47635 JOHNNY
# 47952 CHRIS
# 48250 JOHNNY
# 48848 SUE
# 49362 JOHN
# 50843 DAVID
# 51194 CAROL
# 51360 GUY
# 52653 GUY
# 53650 MARK
# 53767 KEVIN
# 53956 MARCUS
# 53957 GEORGE
# 54185 DAVID
# 54214 TOBY
# 54230 GEORGE
# 54231 HARRY
# 54245 TOM
# 54247 PETER
# 54305 GEORGE
# 54351 PHIL
# 54504 ALAN
# 54836 DREW
# 55015 DAVID
# 55037 NATALIE
# 55112 JULIE

# %%
for i in range(0,len(word_list) -1,1):
    for j in range(0,len(first_nameU)):
        name = (first_nameU[j] + last_nameU[j])
        if ((word_list[i] + word_list[i+1]) == name):
            print(name)
# Out:
# DAVIDCAMERON
# DAVIDCAMERON
# DAVIDCAMERON
# DAVIDCAMERON
