# %% [markdown]
# # Assessment 2 Individual project
# # #Monitoring BBC podcasts
#  submitted by Wanting Chen(MFA)

# %% [markdown]
# # Menu:
# Zero part: Rebuild dataframe into csv form
#
# First part: Exploration
#
#
# Second part: Description
#
#
# Third part: Reflect   and   Hypothesise

# %% [markdown]
# # Zero: Read jaon file and clean the data

# %% [markdown]
# Jason file is hard for me to use and there is really a few data avaliable, so I decided to rebuild new dataframe in order to get the correct data from each speaker.
#
#
#                              *****The Describe part is in the below.******
#
# Our group chose the BBC podcast topic and I decided to analysis one podcast which called "the world this week".
#
#
# I chose two data of two dates: 30.01.2016 and 25.06.2016(two days after the result of 2016 referendum released), in order to see what happened when the 2016 referendum.

# %%
# %%bash
#
# head 20160625_013000_the_world_this_week.asr.json
# pip install ijson
# Out:
# {
#  "speakers": [
#   "s0001",
#   "s0002"
#  ],
#  "classes": [
#   "speech"
#  ],
#  "segments": [
#   {
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly 
import seaborn as sns
plotly.tools.set_credentials_file(username='LuvianChen', api_key='HplTTtmuV86KzNkp0Nv2')

# %%
# %%bash
#
# grep -E '^ {1,5}"' 20160130_013000_the_world_this_week.asr.json
# Out:
#  "speakers": [
#   "s0002",
#   "s0003",
#   "s0001"
#  "classes": [
#   "speech"
#  "segments": [
#    "classId": "speech",
#    "spokenWords": [
#      "wordEnd": 0.41999999999999998,
#      "wordId": "HELLO",
#      "wordStart": 0.040000000000000001,
#      "wordConfidence": 1.0
#      "wordEnd": 0.57999999999999996,
#      "wordId": "I'M",
#      "wordStart": 0.41999999999999998,
#      "wordConfidence": 1.0
#      "wordEnd": 0.88,
#      "wordId": "SHONE",
#      "wordStart": 0.56999999999999995,
#      "wordConfidence": 0.97999999999999998
#      "wordEnd": 1.23,
#      "wordId": "LIKE",
#      "wordStart": 0.89000000000000001,
#      "wordConfidence": 0.97999999999999998
#      "wordEnd": 1.5800000000000001,
#      "wordId": "WELCOME",
#      "wordStart": 1.23,
#      "wordConfidence": 1.0
#      "wordEnd": 1.6699999999999999,
#      "wordId": "TO",
#      "wordStart": 1.5800000000000001,
#      "wordConfidence": 1.0
#      "wordEnd": 1.77,
#      "wordId": "THE",
# ...

# %%
#data = pd.concat(dataframes)
#data = pd.read_json('mark/20160625_013000_the_world_this_week.asr.json')

# %%
import pandas as pd
data = pd.read_json('mark/20160625_013000_the_world_this_week.asr.json')

# %%
words = data['segments'][0]

# %%
word_list = []
long_list  = []
speaker_list = []
new_frame = pd.DataFrame()
for i in words:
    for word in i['spokenWords']:
        word_list.append(word['wordId'])
        long_list.append(word['wordEnd'] - word['wordStart'])
        speaker_list.append(i['speakerId'])
    #print(i['spokenWords'][0]['wordId'])
new_frame['word'] = word_list
new_frame['long'] = long_list
new_frame['speaker'] = speaker_list

# %%
new_frame.to_csv('speech20160625.csv')

# %%
print(new_frame)
# Out:
#           word  long speaker
# 0        HELLO  0.36   s0001
# 1          I'M  0.28   s0001
# 2         JUMA  0.31   s0001
# 3        GIVER  0.27   s0001
# 4          AND  0.21   s0001
# 5      WELCOME  0.41   s0001
# 6           TO  0.12   s0001
# 7            A  0.07   s0001
# 8      SPECIAL  0.41   s0001
# 9      EDITION  0.38   s0001
# 10          OF  0.10   s0001
# 11         THE  0.10   s0001
# 12       WORLD  0.31   s0001
# 13        THIS  0.21   s0001
# 14        WEEK  0.35   s0001
# 15         THE  0.09   s0001
# 16     PROGRAM  0.46   s0001
# 17        THAT  0.12   s0001
# 18       TELLS  0.29   s0001
# 19         YOU  0.15   s0001
# 20         HOW  0.20   s0001
# 21         THE  0.11   s0001
# 22       WORLD  0.29   s0001
# 23         HAS  0.20   s0001
# 24     CHANGED  0.57   s0001
# 25          IN  0.08   s0001
# 26         THE  0.08   s0001
# 27        PAST  0.37   s0001
# 28       SEVEN  0.42   s0001
# 29        DAYS  0.51   s0001
# ...        ...   ...     ...
# ...

# %%
import pandas as pd
data1 = pd.read_csv("speech20160130.csv")
data2 = pd.read_csv("speech20160625.csv")

import numpy as np

# %%
data1.columns=['id','word','long','speaker']
data1
# Out:
#         id      word  long speaker
# 0        0     HELLO  0.38   s0002
# 1        1       I'M  0.16   s0002
# 2        2     SHONE  0.31   s0002
# 3        3      LIKE  0.34   s0002
# 4        4   WELCOME  0.35   s0002
# 5        5        TO  0.09   s0002
# 6        6       THE  0.10   s0002
# 7        7   PROGRAM  0.44   s0002
# 8        8      THAT  0.14   s0002
# 9        9     TELLS  0.31   s0002
# 10      10       YOU  0.14   s0002
# 11      11       HOW  0.32   s0002
# 12      12       THE  0.12   s0002
# 13      13     WORLD  0.28   s0002
# 14      14   CHANGED  0.66   s0002
# 15      15        IN  0.10   s0002
# 16      16       THE  0.09   s0002
# 17      17      PAST  0.36   s0002
# 18      18     SEVEN  0.28   s0002
# 19      19      DAYS  0.43   s0002
# 20      20       THE  0.14   s0002
# 21      21      WELL  0.36   s0002
# 22      22      THIS  0.31   s0002
# 23      23      WEEK  0.36   s0002
# 24      24      THIS  0.22   s0002
# 25      25       WAS  0.19   s0002
# ...

# %%
#a=pd.value_counts(data.loc[data.speaker=='s0003'].word.values).to_frame()
#a

# %%
#tdata = data.drop_duplicates(subset='word', keep="first", inplace=False)
#tdata

# %%
speaker1 = data1[data1['speaker']=='s0001']
speaker2 = data1[data1['speaker']=='s0002']
speaker3 = data1[data1['speaker']=='s0003']
speaker4 = data2[data2['speaker']=='s0001']
speaker5 = data2[data2['speaker']=='s0002']

# %%
word_count = []
for t in speaker1['word']:
    counter = 0
    for w in speaker1['word']:
        if t == w:
            counter = counter + 1
    word_count.append(counter)
speaker1['2016count'] = word_count
speaker1
# Out:
# /Users/luvianluvian/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         id         word  long speaker  2016count
# 666    666         IT'S  0.21   s0001          3
# 667    667          THE  0.09   s0001         46
# 668    668     SYMPTOMS  0.53   s0001          1
# 669    669           OF  0.14   s0001         30
# 670    670         THIS  0.41   s0001          3
# 671    671        VIRUS  0.39   s0001          1
# 672    672           OF  0.20   s0001         30
# 673    673        BEANS  0.30   s0001          1
# 846    846       BABIES  0.51   s0001          1
# 847    847         BORN  0.37   s0001          1
# 848    848         WITH  0.33   s0001          6
# ...

# %%
word_count = []
for t in speaker2['word']:
    counter = 0
    for w in speaker2['word']:
        if t == w:
            counter = counter + 1
    word_count.append(counter)
speaker2['2016count'] = word_count
speaker2
# Out:
# /Users/luvianluvian/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         id      word  long speaker  2016count
# 0        0     HELLO  0.38   s0002          1
# 1        1       I'M  0.16   s0002          3
# 2        2     SHONE  0.31   s0002          1
# 3        3      LIKE  0.34   s0002          5
# 4        4   WELCOME  0.35   s0002          1
# 5        5        TO  0.09   s0002         58
# 6        6       THE  0.10   s0002        165
# 7        7   PROGRAM  0.44   s0002          3
# 8        8      THAT  0.14   s0002         49
# 9        9     TELLS  0.31   s0002          2
# 10      10       YOU  0.14   s0002         10
# 11      11       HOW  0.32   s0002          5
# ...

# %%
word_count = []
for t in speaker3['word']:
    counter = 0
    for w in speaker3['word']:
        if t == w:
            counter = counter + 1
    word_count.append(counter)
speaker3['2016count'] = word_count
speaker3
# Out:
# /Users/luvianluvian/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         id         word  long speaker  2016count
# 50      50          THE  0.20   s0003         39
# 51      51        LEVEL  0.41   s0003          2
# 52      52           OF  0.13   s0003         27
# 53      53      CONCERN  0.49   s0003          3
# 54      54           IS  0.16   s0003         19
# 55      55         HIGH  0.28   s0003          2
# 57      57    QUESTIONS  0.56   s0003          2
# 58      58           OF  0.15   s0003         27
# 59      59         MILD  0.49   s0003          2
# 84      84          YOU  0.14   s0003          7
# 85      85        COULD  0.24   s0003          2
# ...

# %%
word_count = []
for t in speaker4['word']:
    counter = 0
    for w in speaker4['word']:
        if t == w:
            counter = counter + 1
    word_count.append(counter)
speaker4['2016count'] = word_count
speaker4
# Out:
# /Users/luvianluvian/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       Unnamed: 0      word  long speaker  2016count
# 0              0     HELLO  0.36   s0001          1
# 1              1       I'M  0.28   s0001          2
# 2              2      JUMA  0.31   s0001          1
# 3              3     GIVER  0.27   s0001          1
# 4              4       AND  0.21   s0001         34
# 5              5   WELCOME  0.41   s0001          1
# 6              6        TO  0.12   s0001         38
# 7              7         A  0.07   s0001         27
# 8              8   SPECIAL  0.41   s0001          1
# 9              9   EDITION  0.38   s0001          1
# ...

# %%
word_count = []
for t in speaker5['word']:
    counter = 0
    for w in speaker5['word']:
        if t == w:
            counter = counter + 1
    word_count.append(counter)
speaker5['2016count'] = word_count
speaker5
# Out:
# /Users/luvianluvian/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       Unnamed: 0        word  long speaker  2016count
# 57            57           I  0.20   s0002         48
# 58            58        WILL  0.15   s0002         10
# 59            59          DO  0.34   s0002         16
# 60            60  EVERYTHING  0.45   s0002          3
# 61            61           I  0.11   s0002         48
# 62            62         CAN  0.32   s0002          8
# 63            63          AS  0.12   s0002         25
# 64            64       PRIME  0.22   s0002          3
# 65            65    MINISTER  0.38   s0002          3
# 66            66          TO  0.13   s0002         83
# ...

# %% [markdown]
# # Creat new dataframe

# %% [markdown]
# # First part: Exploration

# %%
a = np.array(speaker1)
b = np.array(speaker2)
c = np.array(speaker3)
d = np.array(speaker4)
e = np.array(speaker5)
#print(a.shape)

#so I create two dataframe.
f = np.vstack((a,b,c))
datacount1 = pd.DataFrame(f)
datacount1.columns = ["id", "word", "time", "speaker", "JanuaryFrequency"]

f = np.vstack((d,e))
datacount2 = pd.DataFrame(f)
datacount2.columns = ["id", "word", "time", "speaker", "JuneFrequency"]
datacount2
# Out:
#         id     word  time speaker JuneFrequency
# 0        0    HELLO  0.36   s0001             1
# 1        1      I'M  0.28   s0001             2
# 2        2     JUMA  0.31   s0001             1
# 3        3    GIVER  0.27   s0001             1
# 4        4      AND  0.21   s0001            34
# 5        5  WELCOME  0.41   s0001             1
# 6        6       TO  0.12   s0001            38
# 7        7        A  0.07   s0001            27
# 8        8  SPECIAL  0.41   s0001             1
# 9        9  EDITION  0.38   s0001             1
# 10      10       OF   0.1   s0001            22
# 11      11      THE   0.1   s0001            72
# 12      12    WORLD  0.31   s0001             7
# 13      13     THIS  0.21   s0001            16
# 14      14     WEEK  0.35   s0001             5
# 15      15      THE  0.09   s0001            72
# 16      16  PROGRAM  0.46   s0001             2
# 17      17     THAT  0.12   s0001            15
# 18      18    TELLS  0.29   s0001             2
# ...

# %%
dd1 = datacount1.loc[(datacount1.word=='POLITICAL')]
dd2 = datacount1.loc[(datacount1.word=='TELEVISION')]
dd3 = datacount1.loc[(datacount1.word=='PEOPLE')]
dd4 = datacount1.loc[(datacount1.word=='RUSSIAN')]
dd5 = datacount1.loc[(datacount1.word=="WORLD")]
dd6 = datacount1.loc[(datacount1.word=='DANISH')]
dd7 = datacount1.loc[(datacount1.word=='DENMARK')]
dd8 = datacount1.loc[(datacount1.word=='UP')]
dd9 = datacount1.loc[(datacount1.word=='BRAZIL')]
dd10 = datacount1.loc[(datacount1.word=='PALESTINIANS')]
dd11 = datacount1.loc[(datacount1.word=='CORRUPTION')]
dd12 = datacount1.loc[(datacount1.word=='NETANYAHU')]

popularword1=pd.concat([dd1, dd2,dd3,dd4,dd5,dd6,dd7,dd8,dd9,dd10,dd11,dd12])
#popularword1

# %%
df1 = datacount2.loc[(datacount2.word=='POLITICIANS')]
df2 = datacount2.loc[(datacount2.word=='U.K.')]
df4 = datacount2.loc[(datacount2.word=='GERMAN')]
df5 = datacount2.loc[(datacount2.word=='POLITICS')]
df6 = datacount2.loc[(datacount2.word=='POLITICAL')]
df7 = datacount2.loc[(datacount2.word=="BRITAIN'S")]
df8 = datacount2.loc[(datacount2.word=='BRITISH')]
df9 = datacount2.loc[(datacount2.word=='UNION')]
df10 = datacount2.loc[(datacount2.word=='UP')]
df11 = datacount2.loc[(datacount2.word=='EUROPE')]
df12 = datacount2.loc[(datacount2.word=='CHANGE')]
df13 = datacount2.loc[(datacount2.word=='PEOPLE')]
popularword2=pd.concat([df1, df2,df4,df5,df6,df7,df9,df10,df11,df12,df13])
popularword2
# Out:
#         id         word  time speaker JuneFrequency
# 167    260  POLITICIANS  0.64   s0001             2
# 783   2682  POLITICIANS  0.89   s0001             2
# 2131  1447  POLITICIANS  0.88   s0002            11
# 2135  1451  POLITICIANS  0.74   s0002            11
# 2151  1467  POLITICIANS  0.77   s0002            11
# 2160  1476  POLITICIANS  0.67   s0002            11
# 2182  1498  POLITICIANS  0.84   s0002            11
# 3447  3203  POLITICIANS  0.52   s0002            11
# 3944  3829  POLITICIANS  0.65   s0002            11
# 3956  3841  POLITICIANS  0.59   s0002            11
# 3963  3848  POLITICIANS  0.53   s0002            11
# 4109  3994  POLITICIANS  0.75   s0002            11
# 4128  4013  POLITICIANS  0.64   s0002            11
# 62     106         U.K.   0.4   s0001             7
# 97     190         U.K.  0.54   s0001             7
# 497   1719         U.K.  0.54   s0001             7
# 585   1942         U.K.  0.51   s0001             7
# ...

# %% [markdown]
# # Relationships Analysis1
# 1Exploration of the data below:
# Hot topic in January30th and June25th
#
# The Keywords in popularword1 and popularword2 data framewere chosen by me from the new data frame(datacount1,datacount2),because I find out many repeat words were just filler word which is not I want.
#
#
# From the popularword1, I found out the hot topic (sort from largest to smallest)in January30th is World,Television,People, Russian and Denmark. But in the popularword2, speaker talks more about Politicians, U.K and German. We can also find out some new focus like Britain's and Union. Two diagram share some similarity, they both have 'People', 'Up' and 'Political'these three topic. The word ‘Political’ only appear one time in the popularword1 but several times in popularword2.

# %%
import seaborn as sns
sns.lmplot(x="time", y="JanuaryFrequency", data=popularword1, fit_reg=False, hue='word', legend=False,size=8,markers=["o", "x","s","8","<",">","*","D",".","v","p","P"])

plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# # Explore1 :  Hot topic in June25th
#
# Findings:
# 1Politicians is the hottest topics.
#
# 2 Sometimes speakers speak the word 'people' slowly and sometimes fast.
#
# 3 Two speakers both say the word'U.K' and 'Politics' in different frequency and duration.

# %%
import seaborn as sns
sns.lmplot(x="time", y="JuneFrequency", data=popularword2, fit_reg=False, hue='word', legend=False,size=8,markers=["o", "x","s","8","<",">","*","D",".","v","P"])

plt.legend(loc='lower right')

plt.show()

# %%
print(popularword1['speaker'].value_counts())
# Out:
# s0002    68
# s0001    25
# s0003    18
# Name: speaker, dtype: int64

# %%
pp=popularword1.groupby('word').count()
pp.reset_index()
# Out:
#             word  id  time  speaker  JanuaryFrequency
# 0         BRAZIL  10    10       10                10
# 1     CORRUPTION   5     5        5                 5
# 2         DANISH  11    11       11                11
# 3        DENMARK  11    11       11                11
# 4      NETANYAHU   4     4        4                 4
# 5   PALESTINIANS   6     6        6                 6
# 6         PEOPLE  19    19       19                19
# 7      POLITICAL   1     1        1                 1
# 8        RUSSIAN   9     9        9                 9
# 9     TELEVISION   9     9        9                 9
# 10            UP   9     9        9                 9
# 11         WORLD  17    17       17                17

# %% [markdown]
# labels = pp.T.columns
# values = pp.
# trace = go.Pie(labels=labels,values=values)
# py.iplot([trace],filename='basic_pie')

# %% [markdown]
# # Explore2: The percentage of two speaker in datacount1
#  Findings: Speaker s0002 accounts for 74.6% in datacount1 which is larger than s0001.

# %%
#plt.figure(figsize=(50,40))
#sns.countplot(x='word',data=popularword,hue='speaker',)
#plt.show()
from matplotlib import pyplot as plt 
plt.figure(figsize=(6,9))
#定义饼状图的标签，标签是列表
labels = [u's0001',u's0002']
#每个标签占多大，会自动去算百分比
sizes = [29,85]
colors = ['pink','lightskyblue']
#将某部分爆炸出来， 使用括号，将第一块分割出来，数值的大小是分割出来的与其他两块的间隙
explode = (0.05,0)
patches,l_text,p_text = plt.pie(sizes,explode=explode,labels=labels,colors=colors,
                                labeldistance = 1.1,autopct = '%3.1f%%',shadow = False,
                                startangle = 90,pctdistance = 0.6)
for t in l_text:
    t.set_size=(30)
for t in p_text:
    t.set_size=(20)

plt.axis('equal')
plt.legend()
plt.show()

# %% [markdown]
# This part is to ignore the filler word (such as any, and, the)and try to find out topics.

# %%
t2data1 = datacount1[(datacount1['JanuaryFrequency'] > 1) & (datacount1['JanuaryFrequency'] < 9)]        
t2data1.sort_values(by="JanuaryFrequency",inplace=True)
t2data1
# Out:
# /Users/luvianluvian/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         id          word  time speaker JanuaryFrequency
# 1919  2013      BENJAMIN  0.43   s0002                2
# 2995  3161        FAILED  0.34   s0002                2
# 2998  3164      RUSSIA'S  0.45   s0002                2
# 998    204           ITS  0.15   s0002                2
# 3002  3168           OIL   0.3   s0002                2
# 3005  3171     COUNTRY'S  0.47   s0002                2
# 989    195  PARTICULARLY  0.72   s0002                2
# 3011  3177         RIGHT  0.23   s0002                2
# 3015  3181           SAY  0.37   s0002                2
# 3020  3186           HIM  0.28   s0002                2
# ...

# %%
t2data2 = datacount2[(datacount2['JuneFrequency'] > 6) & (datacount2['JuneFrequency'] < 12)]        
t2data2.sort_values(by="JuneFrequency",inplace=True)
t2data2
# Out:
# /Users/luvianluvian/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         id         word  time speaker JuneFrequency
# 12      12        WORLD  0.31   s0001             7
# 2124  1440           UP  0.21   s0002             7
# 2138  1454       COURSE   0.4   s0002             7
# 2143  1459           UP  0.18   s0002             7
# 2148  1464       COURSE  0.35   s0002             7
# 2150  1466         WERE  0.19   s0002             7
# 2165  1481         MUCH  0.35   s0002             7
# 2200  1581         LOOK  0.32   s0002             7
# 2202  1583         WERE  0.08   s0002             7
# 2277  1658        SENSE  0.35   s0002             7
# 2074  1317    BRITAIN'S  0.37   s0002             7
# ...

# %% [markdown]
# # Separate different speaker

# %%
plt.figure(figsize=(50,10))
sns.countplot(x='word',data=datacount2,hue='speaker')
plt.show()

# %%
# %matplotlib inline
x = pd.Series(datacount1['time'], name="how long they pronounce the word")
chart = sns.distplot(x)
chart.set_title('Distribution of word time in January30th')

# %%
# %matplotlib inline
x = pd.Series(datacount2['time'], name="how long they pronounce the word")
chart = sns.distplot(x)
chart.set_title('Distribution of word time in June25th')

# %%
#sns.barplot(x="speaker", y="long", hue="2016count", data=speaker1)
#plt.show()

# %%
#sns.barplot(x="speaker", y="long", hue="2016count", data=speaker2,)
#plt.show()

# %% [markdown]
# # Explore3 : Habits of different speaker in January30th and June25th
# Exploration of the data below:
#
# 1Speaker2 in January30th and speaker5 in June25th use repeat word a lot.
#
# 2Speaker5 has the largest number of repeat word.
#
# 3Speaker4 speaks one word more frequently than another word he/she said. it might be a habit.

# %%
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Style options available out of the box: darkgrid, whitegrid, dark, white, and ticks
# Palette options available out of the box: deep, muted, pastel, bright, dark, and colorblind.
sns.set(style="white", palette="deep", color_codes=True)


# Set up the matplotlib figure
f, axes = plt.subplots(3, 2, figsize=(20, 20), sharex=True)
sns.despine(left=True)


# Plot a simple histogram with binsize determined automatically
sns.barplot(x="speaker", y="long", hue="2016count", data=speaker1,ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.barplot(x="speaker", y="long", hue="2016count", data=speaker2,ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.barplot(x="speaker", y="long", hue="2016count", data=speaker3,ax=axes[1, 0])

# Plot a historgram and kernel density estimate
sns.barplot(x="speaker", y="long", hue="2016count", data=speaker4,ax=axes[1,1 ])

sns.barplot(x="speaker", y="long", hue="2016count", data=speaker5,ax=axes[2,0 ])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
sns.barplot(x="word", y="2016count", data=speaker1,ax=axes[0, 0])

# %% [markdown]
# # Second part: Description
# my dataframe is a tabular.
#
# The datacount1 is the data in 30.01.2016
# and The datacount2 is the data in 25.06.2016

# %% [markdown]
# statistics about the data:

# %%
#How   many   speaker the podcast in 2016?
datacount1['speaker'].value_counts()
# Out:
# s0002    2378
# s0001     822
# s0003     814
# Name: speaker, dtype: int64

# %%
#How   many   speaker the podcast in 2016?
datacount2['speaker'].value_counts()
# Out:
# s0002    3338
# s0001    1086
# Name: speaker, dtype: int64

# %% [markdown]
# How large is the data?

# %%
datacount1.describe(include='all')
# Out:
#           id  word     time speaker  JanuaryFrequency
# count   4014  4014  4014.00    4014              4014
# unique  4014  1238   460.00       3                35
# top     4013   THE     0.12   s0002                 1
# freq       1   250    89.00    2378              1102

# %%
datacount1.shape[0],datacount2.shape[0]
# Out:
# (4014, 4424)

# %%
datacount2.describe(include='all')
# Out:
#           id  word     time speaker  JuneFrequency
# count   4424  4424  4424.00    4424           4424
# unique  4424  1196   477.00       2             42
# top     4423   THE     0.25   s0002              1
# freq       1   282    93.00    3338            923

# %%
np.max(datacount1['time'])
# Out:
# 1.17999999999995

# %%
np.max(datacount2['time'])
# Out:
# 1.009999999999991

# %%
print ('Times of 3 speakers repeat:',np.max(datacount1['JanuaryFrequency']))
# Out:
# Times of 3 speakers repeat: 165

# %%
print ('Times of 2 speakers repeat:',np.max(datacount2['JuneFrequency']))
# Out:
# Times of 2 speakers repeat: 210

# %%
datacount1[datacount1['word']== 'DANISH']
# Out:
#        id    word  time speaker JanuaryFrequency
# 288  3400  DANISH  0.36   s0001               11
# 337  3449  DANISH  0.41   s0001               11
# 433  3545  DANISH  0.28   s0001               11
# 520  3632  DANISH  0.34   s0001               11
# 565  3677  DANISH   0.3   s0001               11
# 583  3695  DANISH  0.38   s0001               11
# 589  3701  DANISH  0.43   s0001               11
# 653  3765  DANISH   0.3   s0001               11
# 671  3792  DANISH  0.34   s0001               11
# 681  3802  DANISH  0.34   s0001               11
# 784  3905  DANISH  0.33   s0001               11

# %%
# %%bash
#
# pip install wordcloud

# %%
from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
wordcloud2 = WordCloud().generate(' '.join(datacount1['word']))
plt.figure(figsize=(50,10))
plt.imshow(wordcloud2)
plt.axis('off')
plt.show()
wordcloud2 = WordCloud().generate(' '.join(datacount2['word']))
plt.figure(figsize=(50,10))
plt.imshow(wordcloud2)
plt.axis('off')
plt.show()

# %%
tdata = datacount1.sort_values('JanuaryFrequency')

# %%
A = datacount1['time'].mean()
#for i in data['long']:
#    if i > A:
#       print(i)
ndata = datacount1[datacount1['time'] > A]
print(ndata)
# Out:
#         id           word  time speaker JanuaryFrequency
# 2      668       SYMPTOMS  0.53   s0001                1
# 4      670           THIS  0.41   s0001                3
# 5      671          VIRUS  0.39   s0001                1
# 8      846         BABIES  0.51   s0001                1
# 9      847           BORN  0.37   s0001                1
# 10     848           WITH  0.33   s0001                6
# 11     849      UNDERSIDE  0.51   s0001                1
# 18    1559        LOOKING  0.44   s0001                1
# 19    1560    WALKABILITY  0.46   s0001                1
# 21    1562         TOWARD  0.36   s0001                1
# 23    1564          WORDS  0.37   s0001                2
# 30    1576  JUSTIFICATION  0.71   s0001                1
# 33    1579      TERRORISM  0.82   s0001                1
# 34    1580         PERIOD  0.48   s0001                1
# 37    1721      HAPPENING  0.38   s0001                1
# ...

# %% [markdown]
# # Explore4:
# In the 'The speaking speed of each speaker in January' plot, s0002 have more ouliers than the other two speakers.
# But their means is nearly the same.

# %%
plt.title('The speaking speed of each speaker in January')
ax = sns.boxplot(x="speaker", y="time", data=datacount1)
plt.show()
plt.title('The speaking speed of each speaker in June')
ax = sns.boxplot(x="speaker", y="time", data=datacount2)
plt.show()

# %%
#try to find out what is the most long word in the procast
n2data = ndata.sort_values('time')
n2data
#why the longest time  word not the longest word?
# Out:
#         id             word  time speaker JanuaryFrequency
# 3740  1125              FOR  0.31   s0003                5
# 3078  3244        ACCORDING  0.31   s0002                1
# 176   3275             HAVE  0.31   s0001                5
# 72    1847             BEEN  0.31   s0001                4
# 799   3920           LONGER  0.31   s0001                2
# 607   3719             OVER  0.31   s0001                1
# 87    1981            MATCH  0.31   s0001                1
# 599   3711            MONEY  0.31   s0001                1
# 1955  2073             KIND  0.31   s0002                7
# 2980  3146          RUSSIAN  0.31   s0002                9
# 2384  2550          SETTING  0.31   s0002                1
# 2391  2557              ITS  0.31   s0002                2
# 2397  2563              AND  0.31   s0002               43
# 2447  2613            WHITE  0.31   s0002                2
# 372   3484          BRITAIN  0.31   s0001                2
# ...

# %% [markdown]
# # Reflect   and   Hypothesise:

# %% [markdown]
# Reflection:
# From the data, we can see that the topic change significantly because of the 2016 referendums. We can see the speaker's speaking pattern changed, more repeat words were included in one speech. Also from two small charts of 'how long they pronounce the word', we can find out that speakers used to speak in slow speed, but when in June they spoke faster. This is very interesting, before analysing the data, I never thought about the way of speaker speaking will also influenced by the national event, I only thought about the hot subject would definitely change.
# I also find the context of the news also change significantly. Although as we all know it is the referendum that change the focus of the news, but context also provide us the way to understand how the speaker think. We can see when 25June, speakers mostly talk about the present, thoughts of people, politics and leaving.It is also noteworthy that more verb appeared in the context. This makes me think about when there is lots of verb in the context, is it means they have more needs to express their idea or anxiety？I think I need to do more research and data before having a conclusion.
# On the other hand,the word "People"appeared in high frequency in both two data. So it's easy to find out BBC podcast likes to talk about people.

# %% [markdown]
# # Hypothese 1:People will still be the focus of this podcast.

# %% [markdown]
# Reason: In both popularword1 and popularword2, the word'people' appears many times.
# we can also find out from the wordcloud.

# %% [markdown]
# How you could go about testing it: analysis more data about their recent podcast to see if this is true.

# %% [markdown]
# # Hypothese 2:This podcast'the world this week' not always talk about Politics

# %% [markdown]
# Reason: The word ‘Political’ only appear one time in the popularword1(the date30.01.2016). 30.01.2016 is a sample I chose to represent normal days. So as we can see, when there is no Political event, they barely talk about ‘Political’.

# %% [markdown]
# How you could go about testing it: check all data record of 'the world this week' both the past and the future,try to find pattern to see if they have preference.

# %% [markdown]
# # Hypothese 3: 2016 referendum change the national focus

# %%
wordcloud2 = WordCloud().generate(' '.join(datacount1['word']))
plt.figure(figsize=(50,10))
plt.imshow(wordcloud2)
plt.axis('off')
plt.show()
wordcloud2 = WordCloud().generate(' '.join(datacount2['word']))
plt.figure(figsize=(50,10))
plt.imshow(wordcloud2)
plt.axis('off')
plt.show()

# %% [markdown]
# Reason: It's clear from the image, before 25June the topic are mostly about different countries and it's very diverse. But when it comes to 25June, there is less diversity in the word. Mostly about Britain and Politics.

# %% [markdown]
# How you could go about testing it: Check the data of this podcast in following days after 25June. We can also check the data of 2016United States presidential election to see how huge social event change people thinking.

# %% [markdown]
# # Hypothese 4: speakers become much more careful about using words.

# %% [markdown]
# Reason:
# (the boxplot visualization'visualization 'The speaking speed of each speaker in January''The speaking speed of each speaker in June')
#
#
# Compare with the boxplot of 30.01.2016.
# The speaking pattern of two speaker became much more similar. As we can see both the data and the outlier in the boxplot of 25.06.2016 looks nearly the same. I guess because 2016 referendums was a very serious issue, using wrong word in this time period will be cause more problem than normal time. So speakers became more careful when speaking which make the duration of each word more close to average.

# %% [markdown]
# How you could go about testing it: Interview speakers of this podcast to see if it is close to the fact.
